# %%
import ast
import spacy


from bs4 import BeautifulSoup
import pickle
from multiprocessing import Pool, Manager
import time
import pandas as pd
import numpy as np
import re, sys

import csv

import tqdm # optional
import spacy

# %%
DATA_DIR = '/home/user/Dropbox'
input_articles_csv_path = DATA_DIR+'/Data/input_articles.tsv'

def token_rules(doc):
    for tok in doc:
        if (tok.is_stop == False) and (tok.is_punct == False) and (tok.pos_ != 'NUM')  and tok.text != ' ':
            tok.tag_ = u'exclude'
        elif (tok.pos_ == 'NUM' and tok.ent_type_ == 'DATE'):
            tok.text = u'date'

def custom_pipeline(nlp):
    return (nlp.tagger, token_rules, nlp.parser)


def load_data(path, test_frac=0.3, n_articles=None):
    sent_tokens_list = []
    nlp = spacy.load('en', create_pipeline=custom_pipeline)
    return pd.DataFrame(
        iter_file_sent_tokens(
            path=path,
            nlp=nlp,
            n_articles=n_articles,
        )
    )


def iter_file_sent_tokens(path, nlp, n_articles=None):
    """Iterate over the review file and yield sentence tokens.
    
    :param path: Path to the reviews file.
    :type path: str
    :param nlp: Spacy tokenizer with parsing.
    :type nlp: spacy.en.English
    :param n_reviews: Maximum number of reviews to iter over. If
        None we iter over all reviews.
    :type n_reviews: int or NoneType
    
    :returns: Iterator over a dict. See sample output.
    :rtype: iter(dict)
    
    Sample output::
    
        {'review_id': 'iamid', 'sent_num': 0, 'tokens': ['Every', 'villain', 'is', 'lemons']}
    """

    for article in \
        nlp.pipe(
            iter_article_text(path=path, n_articles=n_articles),
            batch_size=2500,
            n_threads=4,
        ):
        for sent_num, sent in enumerate(article.sents):
            yield {
                'sent_num': sent_num,
                'tokens': sent
            }


def iter_article_dict(path, n_articles=None):
    """Iterate over the review file loading the json data into a dict."""
    with open(path, "rt", encoding='utf-8') as infile:
        reader = csv.DictReader(infile, delimiter='\t')
        for i, line in enumerate(reader):
            if n_articles and n_articles == i:
                return
            yield line


def iter_article_text(path, n_articles=None):
    """Iterate over the review text in the review file."""
    for article in iter_article_dict(path=path, n_articles=n_articles):
        html_content = article['content']
#         summary = article['summary']
        title = [article['title']]

        soup = BeautifulSoup(html_content, 'html.parser')
        pis = soup.findAll('p')

        # turn p tags to list of strings
        content = []
        for match in pis:
            text = match.get_text()
            content.append(text)

        # combine all texts to one list of strings for parsing
        content = title + content
        text = '.'.join(content).replace('$','dollar ').replace('%',' percent')
        yield text
        
df = load_data(
    path=input_articles_csv_path,
    test_frac=0,
    n_articles=100,
)
print (len(df.index))
print (df.head(2))
# Out:
# 2779
#    sent_num                                             tokens
# 0         0  (Today, 's, Top, Idea, :, Long, Startek, (, SR...
# 1         1  (Long, SRT, (, Startek, ), by, Omar, A., Samal...

# %%
c=0
with open(input_articles_csv_path, "rt", encoding='utf-8') as infile:
    reader = csv.DictReader(infile, delimiter='\t')
    for row in reader:
        print('\r{}'.format(row))
        c += 1
        if c == 10:
            break
# Out:
# OrderedDict([('article_id', '4189694'), ('publisher_id', ',105512,'), ('category_id', ',17933,'), ('created_at_ts', '2018-07-25 05:00:00'), ('words_count', '182'), ('title', "Today's Top Idea: Long Startek (SRT)"), ('summary', 'NULL'), ('content', '<p><strong>PRO+ Top Idea</strong></p> <p><a href="http://seekingalpha.com/article/4189690-startek-aegis-merger-complete-indiscriminate-selling-due-russell-deletion-leaves-shares">Long SRT (Startek)</a> by Omar A. Samalot; market cap $271M</p> <ul> <li>Business process outsourcer Startek trades at a distressed valuation due to indiscriminate selling following removal from the Russell 2000; given the post closing market cap, rejoining the index next June is almost certain.</li> <li>With the merger complete, Startek/Aegis is a globally diversified powerhouse with &gt;$700M in revenue and a much lower risk profile.</li> <li>Strategic relationship with Amazon is an overlooked catalyst and could drive significant revenue growth over the next year.</li> <li>SRT benefits from the increasing demand for business process outsourcing while the industry remains fragmented with the five largest competitors combined capturing &lt;20% of the global market.</li> <li>The stock trades at just 6.4x 2019 EBITDA; 100%+ upside in the next 24-36 months driven by significant revenue/EBITDA growth, delevering and a modest re-rating more in line with peers.</li> </ul> <p>Wishing you a successful day,</p> <p>- John Leonard, CFA, SA PRO (<a href="mailto:jleonard@seekingalpha.com">jleonard@seekingalpha.com</a>)</p> <p>-------------------</p> <p>PRO+ gives subscribers an exclusive look at one excellent investment idea every day. Please let us know how we can improve -- <a href="mailto:pro-editors@seekingalpha.com">pro-editors@seekingalpha.com</a>.</p>')])
# OrderedDict([('article_id', '4190093'), ('publisher_id', ',105512,'), ('category_id', ',17933,'), ('created_at_ts', '2018-07-26 05:00:00'), ('words_count', '163'), ('title', "Today's Top Idea: Long Gap Inc (GPS)"), ('summary', 'NULL'), ('content', '<p><strong>PRO+ Top Idea</strong></p> <p><a href="http://seekingalpha.com/article/4189444-gap-2-bad-businesses-hiding-2-good-ones">Long GPS (Gap Inc)</a> by Vince Martin (see <a href="https://seekingalpha.com/article/4130527-sa-interview-evaluating-market-expectations-vince-martin">exclusive interview</a>); market cap $11.6B</p> <ul> <li>The mispricing in apparel retailer Gap Inc is because the Gap and Banana Republic brands are mucking up the numbers.</li> <li>However Old Navy alone could support the entire enterprise value, which gives investors the Gap brand, Banana Republic, and athleisure concept Athleta for free.</li> <li>The growth of Old Navy should eventually shine through as the effect of Gap and Banana Republic fades; as management has recognized that Gap and Banana Republic need to be managed appropriately, this probably leads to a further shrinking of those businesses and a focus on profitability.</li> <li>There is ~45% upside (in addition to a ~3% yield) on a SOTP basis.</li> </ul> <p>Wishing you a successful day,</p> <p>- John Leonard, CFA, SA PRO (<a href="mailto:jleonard@seekingalpha.com">jleonard@seekingalpha.com</a>)</p> <p>-------------------</p> <p>PRO+ gives subscribers an exclusive look at one excellent investment idea every day. Please let us know how we can improve -- <a href="mailto:pro-editors@seekingalpha.com">pro-editors@seekingalpha.com</a>.</p>')])
# OrderedDict([('article_id', '4190856'), ('publisher_id', ',105512,'), ('category_id', ',17994,'), ('created_at_ts', '2018-07-27 05:00:00'), ('words_count', '160'), ('title', "Today's Top Idea: Short Care.Com (CRCM)"), ('summary', 'NULL'), ('content', '<p><strong>PRO+ Top Idea</strong></p> <p><a href="http://seekingalpha.com/article/4190716-care-free-approach-reporting-earnings-care-com">Short CRCM (Care.Com)</a> by Lord Baltimore; market cap $681M</p> <ul> <li>Care.com, an online matching service for caregivers, has been beating EPS expectations of late but the quality of those earnings is low given questionable add-backs and omissions.</li> <li>Despite reduced customer acquisition costs, the lifetime value and ROI on incremental subscribers may be overstated and growth in the core U.S. matching business has slowed.</li> <li>The recent anemic subscriber and revenue growth does not warrant a 4x revenue multiple or 24x EBITDA multiple.</li> <li>There is ~30%+ downside as even on the inflated 2018 non-GAAP EPS consensus estimate of $0.68, a $15 share price would represent a P/E of &gt;20x, which seems high for a company growing &lt;10% a year.</li> </ul> <p>Wishing you a successful day,</p> <p>- John Leonard, CFA, SA PRO (<a href="mailto:jleonard@seekingalpha.com">jleonard@seekingalpha.com</a>)</p> <p>-------------------</p> <p>PRO+ gives subscribers an exclusive look at one excellent investment idea every day. Please let us know how we can improve -- <a href="mailto:pro-editors@seekingalpha.com">pro-editors@seekingalpha.com</a>.</p>')])
# OrderedDict([('article_id', '4191092'), ('publisher_id', ',105512,577712,577463,'), ('category_id', ',1936,'), ('created_at_ts', '2018-07-28 07:30:00'), ('words_count', '6258'), ('title', 'SA Interview: Bottom-Up Fundamental Investing With Greystone Capital'), ('summary', '["Greystone Capital is a long-only investment partnership that focuses on buying quality businesses at favorable prices with a long-term holding period.","Greystone Capital’s competitive advantage, what they look for in long ideas, and how they find them are topics discussed.","Greystone Capital shares a long thesis on Select Sands and The Joint Corp."]'), ('content', '<p><strong>Feature interview</strong></p> <p><a href="https://seekingalpha.com/author/greystone-capital/articles#regular_articles?source=pro_newsletter_interview">Greystone Capital</a> is a long-only investment partnership that focuses on buying quality businesses at favorable prices with a long-term holding period. SA PRO Editor John Leonard, CFA, discussed with Greystone Capital the “pound the rock” approach, how they use the “scuttlebutt” approach popularized by Philip Fisher and Peter Lynch, and why sometimes the best trade is the one you don’t make.</p> <p><strong>John Leonard, CFA:</strong> You run a long-only, concentrated fund – what qualities do you look for in a long idea?</p> <p><strong>Greystone Capital:</strong> The short answer would be that I am seeking to invest in high-quality businesses run by high-quality management teams that generate significant free cash flow and are trading at cheap valuations on an absolute and/or relative basis. There’s a lot to unpack there.</p> <p>When researching new ideas for the portfolio, I have a checklist of criteria I keep in mind, as well as certain business characteristics I love. These can include, among other things:</p> <ul> <li>Off the beaten path, uncovered by analysts, unloved</li> <li>Cheap valuation relative to intrinsic value</li> <li>Aligned and high-quality management team</li> <li>Strong downside protection via cheapness, cash flows, assets</li> <li>Significant upside, take private value, M&amp;A, asset liquidation, discount to peers despite similar growth and margin targets</li> <li>Clean balance sheet</li> <li>Long runway for growth with some favorable macro tailwinds</li> </ul> <p>Given the concentrated nature of the portfolio, I place an incredible amount of emphasis on bottom up, fundamental research, making sure I understand the key drivers of a business, unit economics, and identify all potential areas of risk that may result in a permanent loss of capital. I look first and foremost for situations deemed to be asymmetric, meaning low downside risk with a high amount of upside. Long ideas are initially filtered by a few simple but important criteria, including an easily understandable business model, a clean balance sheet, long runway for growth, discount to peers, high insider ownership, and high free cash flow yield (or path to one). These investments are difficult to find, even among small less followed companies, so I don’t place a ton of weight on checking every single box right away. If a business is unprofitable from a GAAP standpoint, for example, but all of the other criteria are present, and there seems to exist a clear path toward free cash flow generation and growth, often times, I’ll take a deeper dive into the situation. Because the above description is very hard to find especially at an attractive valuation, often times, when I initially come across a potential investment, the business looks a bit hairy or is going through some negative situation which has caused the undervaluation to exist. I think it’s important to be rigid in terms of one’s investment philosophy and what might constitute a good addition to the portfolio but also remain flexible and open-minded as there are many things that matter in business and investing that aren’t reflected in GAAP financials or my own personal checklist.</p> <p>My aim  ...
# OrderedDict([('article_id', '4191188'), ('publisher_id', ',105512,'), ('category_id', ',1936,'), ('created_at_ts', '2018-07-29 07:30:00'), ('words_count', '590'), ('title', 'PRO+ Weekly Digest: Focusing On Shorting Value Traps'), ('summary', '["We highlight a PRO+ long idea on Copart that played out.","Revisiting the bullish thesis on Andeavor Logistics.","Our idea screen of the week takes a look at shorting value traps."]'), ('content', '<p><em>Welcome to the latest issue of the PRO+ Weekly Digest in which we publish highlights from our PRO+ coverage. Email us at pro-editors at seekingalpha.com to let us know what you think. Find past editions </em><a href="http://seekingalpha.com/author/sa-pro-editors/articles?source=pro_newsletter_intro"><em>here</em></a><em>. PRO+ subscribers can access interviews by following the PRO+ Interviews account and view past interviews under the same account.</em></p> <p>Click <a href="http://seekingalpha.com/article/4191092-sa-interview-bottom-fundamental-investing-greystone-capital">here</a> to read the interview with Greystone Capital.</p> <p><strong>PRO+ idea playing out</strong></p> <p>In December 2017, Michael Boyd shared his <a href="https://seekingalpha.com/article/4134085-copart-upside-way-q1-2018-blowout?source=pro_newsletter_po">bullish thesis</a> on Copart (CPRT), that it had a defensible moat, healthy/improving balance sheet, asset-light business model that throws off a lot of cash and was a prime beneficiary of corporate tax reform. Boyd said the 12% gain in reaction to Q1 2018 earnings understated the strength of the business, which it appears to have done as the stock is up ~30% since then, likely due to the continued strong growth (beat on the top/bottom line in mrq, revenue +28% and non-GAAP EPS +40%).<b><br></b></p> <p><strong>Call from the archive - ANDX</strong></p> <p>Although Andeavor Logistics (ANDX) is up ~5% since Thomas Lott shared his <a href="https://seekingalpha.com/article/4168193-andeavor-logistics-high-quality-mlp-30minus-40-percent-upside-trades-9_5-percent-yield?source=pro_newsletter_archive">bullish thesis</a> three months ago, as the subsequent earnings release appears to validate the thesis (increased 2020 net earnings target represents 60% growth over 2017, announced a $1.6-1.7B drop down and asset transfer expected to close in August 2018 and three new Permian crude oil gathering projects, earlier this month, it announced the 29th consecutive quarterly distribution increase) and with ~35% upside, this may be worth another look.<b><br></b></p> <p><strong>Noteworthy ideas from the past week</strong></p> <p>Short <a href="https://seekingalpha.com/article/4188744-plymouth-industrial-reit-institutions-will-buy-stock-find-retail-investor">PLYM (Plymouth Industrial REIT)</a> by Old Time REITster</p> <p>Long <a href="https://seekingalpha.com/article/4189276-winter-coming-enservco-means-return-profitability-50-percent-upside">ENSV (Enservco)</a> by Michael Madden, CFA</p> <p>Long <a href="https://seekingalpha.com/article/4189690-startek-aegis-merger-complete-indiscriminate-selling-due-russell-deletion-leaves-shares">SRT (StarTek)</a> by Omar A. Samalot</p> <p>Long <a href="https://seekingalpha.com/article/4189444-gap-2-bad-businesses-hiding-2-good-ones">GPS (Gap Inc)</a> by Vince Martin</p> <p>Short <a href="https://seekingalpha.com/article/4190716-care-free-approach-reporting-earnings-care-com">CRCM (Care.com)</a> by Lord Baltimore</p> <p>Short <a href="https://seekingalpha.com/article/4190866-enphase-energy-sham-turnaround">ENPH (Enphase Energy)</a> by Prescience Point</p> <p><strong>Idea screen of the week</strong></p> <p><em>Each week we use the </em><a href="http://seekingalpha.com/pro/idea-filter?source=pro_newsletter_idea_screen"><em>PRO+ Idea Filter</em></a><em> to find potential ideas based on a recent news event. This week, PRO Editor John Leonard, CFA looks at shorting value traps.</em></p> <p>While it’s tempting to short a stock where the consensus is th ...
# OrderedDict([('article_id', '4191692'), ('publisher_id', ',105512,'), ('category_id', ',17862,'), ('created_at_ts', '2018-07-30 05:00:00'), ('words_count', '197'), ('title', "Today's Top Idea: Long Cobalt 27 (CBLLF)"), ('summary', 'NULL'), ('content', '<p><strong>PRO+ Top Idea</strong></p> <p><a href="http://seekingalpha.com/article/4189921-cobalt27-emerging-name-currently-available-discount">Long CBLLF (Cobalt 27)</a> by Itinerant; market cap 603M CAD</p> <ul> <li>Pre-revenue cobalt mining company Cobalt 27 uses the proven metals streaming business model to create the go-to name for investors seeking cobalt exposure; cobalt is an essential ingredient for lithium-ion batteries and critical material for the electric vehicle revolution while highly favorable supply/demand dynamics should drive higher cobalt prices.</li> <li>Two recent stream acquisitions provide growth visibility to 2021 and beyond while the quality/longevity of its assets and counterparties provide stable cash flows.</li> <li>The sell off in the stock due to a pullback in the price of the underlying metal provides a highly advantageous entry point.</li> <li>There is 80%+ upside over the next few years using conservative assumptions, as cash flow increases, more deals are closed and the stock is re-rated closer to peers.</li> <li>The downside is limited by the SOTP value while its physical cobalt holdings alone represent 44% of the enterprise value.</li> </ul> <p>Wishing you a successful day,</p> <p>- John Leonard, CFA, SA PRO (<a href="mailto:jleonard@seekingalpha.com">jleonard@seekingalpha.com</a>)</p> <p>-------------------</p> <p>PRO+ gives subscribers an exclusive look at one excellent investment idea every day. Please let us know how we can improve -- <a href="mailto:pro-editors@seekingalpha.com">pro-editors@seekingalpha.com</a>.</p>')])
# OrderedDict([('article_id', '4192142'), ('publisher_id', ',105512,'), ('category_id', ',17933,'), ('created_at_ts', '2018-07-31 05:00:00'), ('words_count', '193'), ('title', "Today's Top Idea: Long Tech Data (TECD)"), ('summary', 'NULL'), ('content', '<p><strong>PRO+ Top Idea</strong></p> <p><a href="http://seekingalpha.com/article/4191134-tech-data-great-business-bargain-basement-valuation">Long TECD (Tech Data)</a> by Thomas Lott (see <a href="https://seekingalpha.com/article/4131151-sa-interview-contrarian-investing-thomas-lott">exclusive interview</a>); market cap $3.1B</p> <ul> <li>IT products distributor Tech Data is an extremely well-run company that generates slow but steady growth, tons of FCF and solid ROE year in and year out; as a distributor of IT products, it doesn’t matter who wins the tech wars - it only matters that tech spending continues upward.</li> <li>The stock has traded poorly over the past year due to concerns over heightened industry competition and missed earnings expectations however EPS is still expected to grow 14% this year while TECD enjoys a huge moat and gross margins have actually increased.</li> <li>The valuation is compelling at only 8.2x 2018 earnings, 6.4x EBITDA and 14.4% FCF yield.</li> <li>There is 30-80% upside if TECD were to trade at its normalized range of 10-14x earnings, which are still quite conservative multiples given the attractiveness of this business.</li> </ul> <p>Wishing you a successful day,</p> <p>- John Leonard, CFA, SA PRO (<a href="mailto:jleonard@seekingalpha.com">jleonard@seekingalpha.com</a>)</p> <p>-------------------</p> <p>PRO+ gives subscribers an exclusive look at one excellent investment idea every day. Please let us know how we can improve -- <a href="mailto:pro-editors@seekingalpha.com">pro-editors@seekingalpha.com</a>.</p>')])
# OrderedDict([('article_id', '4192430'), ('publisher_id', ',489086,'), ('category_id', 'NULL'), ('created_at_ts', '2018-08-31 09:30:00'), ('words_count', '1176'), ('title', 'Top Idea Author Directory - August 2018'), ('summary', '["Every day, Seeking Alpha editors hunt for the strongest single-stock articles with quantifiable opportunities that can help make investors money.","Every day, one Top Idea article is released to PRO+ subscribers.","Below is the August directory of authors who have obtained a Top Idea since April 2018."]'), ('content', '<p><strong>Seeking Alpha\'s Top Idea Author Directory</strong></p> <p>Seeking Alpha PRO+ selects the best uncovered investment ideas published on Seeking Alpha each market day. The authors who have obtained this distinction are listed below in alphabetical order.</p> <p>Under "Focus," one can find an author\'s investment style and their tendency to go long or short. Industries where the author has obtained a Top Idea designation is listed in the row below their name. One can find an author\'s most recent article by clicking the ticker under "Last article."</p> <p>Please let us know what other information might be helpful in the comment section.</p> <table> <tr> <td>Author</td> <td>Focus</td> <td>Last article</td> </tr> <tr> <td><a href="https://seekingalpha.com/author/bang-for-the-buck"><b>Bang For The Buck</b></a></td> <td><i>Value / Long</i></td> <td><a href="https://seekingalpha.com/article/4186725">AUCOY</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>Metals</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/ben-comston"><b>Ben Comston</b></a></td> <td><i>Value / Long</i></td> <td><a href="https://seekingalpha.com/article/4186605">MIICF</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>Telecom Services - Foreign</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/benjamin-rowles"><b>Benjamin Rowles</b></a></td> <td><i>Growth / Value / Long</i></td> <td><a href="https://seekingalpha.com/article/4187114">NFX</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>Independent Oil &amp; Gas, Independent Oil &amp; Gas</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/cdm-capital"><b>CDM Capital</b></a></td> <td><i>Event &amp; Special Situations / Long</i></td> <td><a href="https://seekingalpha.com/article/4182448">SD</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>Oil &amp; Gas Drilling &amp; Exploration</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/cashflow-hunter"><b>CashFlow Hunter</b></a></td> <td><i>Deep value / Value / Long</i></td> <td><a href="https://seekingalpha.com/article/4174120">TIPT</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>Property &amp; Casualty Insurance</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/dan-stringer"><b>Dan Stringer</b></a></td> <td><i>Value / Long</i></td> <td><a href="https://seekingalpha.com/article/4188406">TST</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>Internet Information Providers</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/dane-bowler"><b>Dane Bowler</b></a></td> <td><i>Special Situations / Growth / Value / Long</i></td> <td><a href="https://seekingalpha.com/article/4179474">ILPT</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>REIT - Industrial, REIT - Office, Property Management, REIT - Diversified</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/dayton-investing"><b>Dayton Investing</b></a></td> <td><i>Deep value / Value / Long</i></td> <td><a href="https://seekingalpha.com/article/4176668">SPLP</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>Industrial</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/deep-value-one"><b>Deep Value One</b></a></td> <td><i>Deep value / Value / Long</i></td> <td><a href="https://seekingalpha.com/article/4167366">AVHI</a></td> </tr> <tr> <td> </td> <td colspan="2"><i>Residential Construction</i></td> </tr> <tr> <td><a href="https://seekingalpha.com/author/donostia"><b>D ...
# OrderedDict([('article_id', '4192717'), ('publisher_id', ',105512,'), ('category_id', ',17933,'), ('created_at_ts', '2018-08-01 05:00:00'), ('words_count', '193'), ('title', "Today's Top Idea: Short Essendant (ESND)"), ('summary', 'NULL'), ('content', '<p><strong>PRO+ Top Idea</strong></p> <p><a href="http://seekingalpha.com/article/4192497-essendant-leveraged-melting-ice-cube-valued-false-hope">Short ESND (Essendant)</a> by TurnOverRocks; market cap $627M</p> <ul> <li>ESND, a wholesale supplier of workplace items, is valued as if it has substantial growth prospects and benefits from a bidding war but in reality, its profits continue to decline rapidly and it has only one cash offer.</li> <li>The stock trades for a 40%+ premium to Sycamore’s cash offer of $11.50 per share while Sycamore has a history of not completing acquisitions and lowering its offers.</li> <li>ESND operates in a secularly-challenged business with continually deteriorating fundamentals, has a massive debt burden and a revolving door of management with low insider ownership.</li> <li>ESND appears overvalued on a standalone and pro forma basis, trading at ~14x LTM EBITDA and ~12.5x EBITDA, respectively; it has historically traded for ~7.5x EBITDA while ODP is trading for ~4.5x EBITDA and Sycamore paid ~5.5x EBITDA for Staples last year.</li> <li>There is ~50% downside on a weighted-average basis.</li> </ul> <p>Wishing you a successful day,</p> <p>- John Leonard, CFA, SA PRO (<a href="mailto:jleonard@seekingalpha.com">jleonard@seekingalpha.com</a>)</p> <p>-------------------</p> <p>PRO+ gives subscribers an exclusive look at one excellent investment idea every day. Please let us know how we can improve -- <a href="mailto:pro-editors@seekingalpha.com">pro-editors@seekingalpha.com</a>.</p>')])
# OrderedDict([('article_id', '4193328'), ('publisher_id', ',105512,'), ('category_id', ',17810,'), ('created_at_ts', '2018-08-02 05:00:00'), ('words_count', '197'), ('title', "Today's Top Idea: Long Athabasca Oil (ATHOF)"), ('summary', 'NULL'), ('content', '<p><strong>PRO+ Top Idea</strong></p> <p><a href="http://seekingalpha.com/article/4192453-athabasca-oil-best-way-play-oil-sands-recovery">Long ATHOF (Athabasca Oil)</a> by Cornerstone Investments; market cap 891M CAD</p> <ul> <li>Oil sands producer Athabasca Oil is the best way to benefit from the upcoming recovery in the Canadian oil sands industry, given its solid balance sheet and massive torque in cash flows to oil prices.</li> <li>The WCS differential should return to historical levels in the near-term, driven by the Keystone pipeline being restored to full capacity and recent approval of the Enbridge Line 3 Replacement project; if the discount narrows by $5, cash flow would improve by ~$65M.</li> <li>Proceeds from a potential monetization of its thermal oil infrastructure assets at a much higher multiple than where the stock trades could be used for debt repayment and expanding capital programs.</li> <li>The stock trades at 6.1x EV/DACF, below a normalized multiple of 8.0x; there is 40%+ upside using conservative assumptions while Q2 earnings could be the inflection point that results in a sentiment change.</li> </ul> <p>Wishing you a successful day,</p> <p>- John Leonard, CFA, SA PRO (<a href="mailto:jleonard@seekingalpha.com">jleonard@seekingalpha.com</a>)</p> <p>-------------------</p> <p>PRO+ gives subscribers an exclusive look at one excellent investment idea every day. Please let us know how we can improve -- <a href="mailto:pro-editors@seekingalpha.com">pro-editors@seekingalpha.com</a>.</p>')])

# %%
reader = pd.read_csv(input_articles_csv_path, encoding = 'utf-8', sep='\t', iterator=True, nrows=10, chunksize=1)

row = reader.get_chunk(1)
print(row['article_id'])

for row in reader:
    print(row['article_id'])
# Out:
# 0    4189694
# Name: article_id, dtype: int64
# 1    4190093
# Name: article_id, dtype: int64
# 2    4190856
# Name: article_id, dtype: int64
# 3    4191092
# Name: article_id, dtype: int64
# 4    4191188
# Name: article_id, dtype: int64
# 5    4191692
# Name: article_id, dtype: int64
# 6    4192142
# Name: article_id, dtype: int64
# 7    4192430
# Name: article_id, dtype: int64
# 8    4192717
# Name: article_id, dtype: int64
# 9    4193328
# Name: article_id, dtype: int64

# %%
def token_rules(doc):
    for tok in doc:
        if (tok.is_stop == False) and (tok.is_punct == False) and (tok.pos_ != 'NUM')  and tok.text != ' ':
            tok.tag_ = u'exclude'
        elif (tok.pos_ == 'NUM' and tok.ent_type_ == 'DATE'):
            tok.text = u'date'

def custom_pipeline(nlp):
    return (nlp.tagger, token_rules, nlp.parser)

nlp = spacy.load('en', create_pipeline=custom_pipeline)

def parsePipeSents(doc):
    
    sentences = list()

    html_content = doc[0]
    summary = doc[1]
    title = [doc[2]]

    soup = BeautifulSoup(html_content, 'html.parser')
    pis = soup.findAll('p')

    # turn p tags to list of strings
    content = []
    for match in pis:
        text = match.get_text()
        content.append(text)

    # combine all texts to one list of strings for parsing
    content = title + summary + content
    text = '.'.join(content).replace('$','dollar ').replace('%',' percent')
    
    parsed = nlp.pipe(text, batch_size=100, n_threads=4)

    return ' '.join(parsed.sents)

def loadInputCSV(path):
    news_df = pd.read_csv(path, encoding = 'utf-8', sep='\t', nrows = 100)

    content = news_df['content'].apply(nan_to_str).tolist()
    summary = [ast.literal_eval(x) for x in news_df['summary'].apply(nan_to_list)]
    news_df['created_at_ts'] = pd.to_datetime(news_df['created_at_ts']).astype(np.int64) // 10 ** 9
    
    sentences = [parsePipeSents(doc) for doc in zip(content, summary, news_df.title.tolist())]

    print ("\nParesed {} sentences".format(len(sentences)))

    assert len(sentences) == len(news_df.index)
    #Concatenating all available text
    news_df['full_text'] = np.asarray(sentences)

    return news_df

# %%
def deserialize(filename):
    with open(filename, 'rb') as handle:
#     with tf.gfile.Open(filename, 'rb') as handle:
        return pickle.load(handle)

def parseSents(args):
    sentences = list()
    doc, q = args

    html_content = doc[0]
    summary = doc[1]
    title = [doc[2]]

    soup = BeautifulSoup(html_content, 'html.parser')
    pis = soup.findAll('p')

    # turn p tags to list of strings
    content = []
    for match in pis:
        text = match.get_text()
        content.append(text)

    # combine all texts to one list of strings for parsing
    content = title + summary + content
    text = '.'.join(content).replace('$','dollar ').replace('%',' percent')
    
    parsed = nlp(text)
    for sent in parsed.sents:
        current_sen = []
        for tok in sent:
            if (tok.is_stop == False) and (tok.is_punct == False) and (tok.pos_ != 'NUM')  and tok.text != ' ':
                current_sen.append(tok.lemma_.lower())
            elif (tok.pos_ == 'NUM' and tok.ent_type_ == 'DATE'):
                current_sen.append('date')

        sentences.append(current_sen)

    flat_sentences = [item for sublist in sentences for item in sublist]

    return ' '.join(flat_sentences)


def nan_to_list(value):
    return '[]' if type(value) == float else value

def nan_to_cat(value):
    return ',-1,' if type(value) == float else value

def nan_to_str(value):
    return '' if type(value) == float else value

def load_input_csv(path):
    news_df = pd.read_csv(path, encoding = 'utf-8', sep='\t', nrows = 100)

    content = news_df['content'].apply(nan_to_str).tolist()
    summary = [ast.literal_eval(x) for x in news_df['summary'].apply(nan_to_list)]
    news_df['created_at_ts'] = pd.to_datetime(news_df['created_at_ts']).astype(np.int64) // 10 ** 9

    t0 = time.time()
    p = Pool()
    m = Manager()
    q = m.Queue()

    args = [(i, q) for idx, i in enumerate(zip(content, summary, news_df.title.tolist()))]

    result = p.map_async(parseSents, args, chunksize=1)

    while not result.ready():
        remaining = result._number_left * result._chunksize
        t = time.time() - t0
        sys.stderr.write('\rRemaining: {0:} Elapsed: {1:7.3f}'.format(remaining,  t))
        sys.stderr.flush()
        time.sleep(1)

    sentences = result.get()

    print ("\nParesed {} sentences".format(len(sentences)))

    assert len(sentences) == len(news_df.index)
    #Concatenating all available text
    news_df['full_text'] = np.asarray(sentences)
    # news_df['full_text'] = (news_df['title'].apply(nan_to_str) + ". " + \
    #                         news_df['summary'].apply(nan_to_str) + ". " + \
    #                         news_df['content'].apply(nan_to_str)
    #                    ).apply(clean_and_filter_first_sentences)

    return news_df

# %%
DATA_DIR = '/home/user/Dropbox'
input_articles_csv_path = DATA_DIR+'/Data/input_articles.tsv'
input_word_embeddings_path = DATA_DIR+'/articles_word2vec/w2v_model'

df = load_input_csv(input_articles_csv_path)
# Out:
# Remaining: 5 Elapsed:  21.16647
# Paresed 100 sentences
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-26:
# Traceback (most recent call last):
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-23:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/user/anaconda3/envs/chameleon/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
DATA_DIR = '/home/user/Dropbox'
input_articles_csv_path = DATA_DIR+'/Data/input_articles.tsv'
input_word_embeddings_path = DATA_DIR+'/articles_word2vec/w2v_model'

df = loadInputCSV(input_articles_csv_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-0d36e498db0c> in <module>
#       3 input_word_embeddings_path = DATA_DIR+'/articles_word2vec/w2v_model'
#       4
# ----> 5 df = loadInputCSV(input_articles_csv_path)
#
# <ipython-input-57-7bbb80cdb380> in loadInputCSV(path)
#      94     news_df['created_at_ts'] = pd.to_datetime(news_df['created_at_ts']).astype(np.int64) // 10 ** 9
#      95
# ---> 96     sentences = [parsePipeSents(doc) for doc in zip(content, summary, news_df.title.tolist())]
#      97
#      98     print ("\nParesed {} sentences".format(len(sentences)))
#
# <ipython-input-57-7bbb80cdb380> in <listcomp>(.0)
#      94     news_df['created_at_ts'] = pd.to_datetime(news_df['created_at_ts']).astype(np.int64) // 10 ** 9
#      95
# ---> 96     sentences = [parsePipeSents(doc) for doc in zip(content, summary, news_df.title.tolist())]
#      97
#      98     print ("\nParesed {} sentences".format(len(sentences)))
#
# <ipython-input-57-7bbb80cdb380> in parsePipeSents(doc)
#      39     parsed = nlp.pipe(text, batch_size=100, n_threads=4)
#      40
# ---> 41     return ' '.join(parsed.sents)
#      42
#      43 def parseSents(args):
#
# AttributeError: 'generator' object has no attribute 'sents'

# %%
input_articles_csv_path = '/home/user/Dropbox/Data/processed_articles.pickle'

df = deserialize(input_articles_csv_path)

# %%
DATA_DIR = '/home/user/Dropbox'
input_articles_csv_path = DATA_DIR + '/pickles/acr_label_encoders.pickle'

acr_label_encoders = deserialize(input_articles_csv_path)

# %%
type(acr_label_encoders['publisher_id'])
# Out:
# sklearn.preprocessing.label.LabelEncoder

# %%
type(acr_label_encoders['category_id'])
# Out:
# sklearn.preprocessing.label.LabelEncoder

# %%
df.head()
# Out:
#    id_encoded  categoryid_encoded  publisherid_encoded  created_at_ts  \
# 0           0                 476                   32     1532494800
# 1           1                 476                   32     1532581200
# 2           2                 490                   32     1532667600
# 3           3                 513                   48     1532763000
# 4           4                 513                   32     1532849400
#
#    text_length                                           text_int
# 0           47  [69, 1853, 3082, 631, 47, 14720, 20110, 1, 1, ...
# 1           49  [69, 1853, 3082, 631, 47, 1222, 1, 6035, 1, 1,...
# 2           47  [69, 1853, 3082, 631, 171, 572, 4042, 34059, 1...
# 3         3653  [1977, 2528, 2744, 2152, 570, 1012, 1, 17339, ...
# 4          405  [984, 640, 1091, 3845, 121, 6849, 11456, 51, 2...

# %%
df.categoryid_encoded.describe()
# Out:
# count    6683.000000
# mean      432.359270
# std       116.092787
# min         0.000000
# 25%       375.000000
# 50%       461.000000
# 75%       521.000000
# max       540.000000
# Name: categoryid_encoded, dtype: float64

# %%
df.categoryid_encoded.value_counts()
# Out:
# 526    763
# 537    519
# 363    357
# 490    239
# 491    216
# 519    188
# 461    166
# 0      165
# 415    162
# 375    155
# 416    150
# 477    147
# 521    143
# 476    141
# 460    120
# 451    112
# 433    101
# 432     99
# 517     99
# 384     99
# 540     95
# 353     94
# 444     92
# 399     86
# 513     79
# 339     64
# 445     62
# 340     60
# 338     58
# 472     54
#       ...
# 187      1
# 259      1
# 191      1
# 501      1
# 527      1
# 195      1
# 482      1
# 7        1
# 443      1
# 167      1
# 389      1
# 35       1
# 31       1
# 365      1
# 283      1
# 279      1
# 377      1
# 381      1
# 275      1
# 393      1
# 267      1
# 397      1
# 27       1
# 23       1
# 409      1
# 19       1
# 15       1
# 271      1
# 425      1
# 171      1
# Name: categoryid_encoded, Length: 541, dtype: int64

# %%
l = df.category_id.loc[1].split(',')
list(filter(None,l))
# Out:
# ['17933']

# %%
def order_str(string):
    
    string = string.split(',')
    string = list(filter(None, string))
    string = sorted(string)
    return ','.join(string)

category = df.category_id.apply(nan_to_cat)
category = category.apply(order_str)

category.value_counts()
# Out:
# 1936          19
# 17933         15
# -1            12
# 17862         12
# 17994          9
# 17810          7
# 17896          7
# 17829          5
# 17913          5
# 17933,2227     2
# 17810,1936     1
# 2227           1
# 17862,2227     1
# 17994,1936     1
# 17862,1936     1
# 17913,1936     1
# 17896,1936     1
# Name: category_id, dtype: int64
